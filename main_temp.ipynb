# %% [markdown]
# # Initial problem resolution

# %%
using CSV
using DataFrames
using Plots
using JuMP
using Gurobi
using Pkg
using TikzGraphs
using Graphs
import GraphPlot
import Colors

# %% [markdown]
# Let's start by creating everything we need.

# %%
bus_system = CSV.read("IEEE_33_bus_system.csv", DataFrame)
bus_system[1:5, :]

buses = 1:33
# Out:
# 1:33

# %% [markdown]
# ## Sets

# %%
Lines = []
for i in 1:size(bus_system, 1)
    if bus_system[i, :"From bus"] != bus_system[i, :"To bus"]
        push!(Lines, (bus_system[i, :"From bus"], bus_system[i, :"To bus"]))
    end
end

g = SimpleGraph(33) 
for (u, v) in Lines
    add_edge!(g, u, v)
end
GraphPlot.gplot(g, nodefillc=map(x -> RGB(0.2,0.5,0.7), 1:nv(g)))
# Out:
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.617309717643326cx, -0.18242528191419743cy), (0.5136154073425192cx, -0.13780072709642938cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.45103769113727143cx, -0.08340822634408104cy), (0.3155584752282884cx, 0.13950177658296645cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.4874402095244723cx, -0.16187120683667114cy), (0.555617608702786cx, -0.3657830887494867cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.2512173914229288cx, 0.1890141705994681cy), (0.035505760247022636cx, 0.25270177077488776cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.3090263540445706cx, 0.21713463524405469cy), (0.38568854825550036cx, 0.4100624812053088cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.04752080962059946cx, 0.27878033381691564cy), (-0.24558999584913488cx, 0.34476893237300416cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.32804731406870397cx, 0.3726330569664698cy), (-0.5163698567844852cx, 0.4371708236606243cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.59221010766306cx, 0.42497641462744634cy), (-0.7193788529725309cx, 0.3285012220535193cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.5667449363430842cx, 0.4938139165419994cy), (-0.5991023558207407cx, 0.6433142102530417cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.7862425873687814cx, 0.27291376930050926cy), (-0.8960978761569086cx, 0.1729819012476703cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.598372446262027cx, -0.9029238023639035cy), (0.5583995555737549cx, -0.9636491815754589cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.4068879288610651cx, 0.49372208102497983cy), (0.4253320338497391cx, 0.6491385650042945cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.41670000921730393cx, 0.7336413030454217cy), (0.38168437355872004cx, 0.8386994951522141cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.5991986261264304cx, 0.7284040317972681cy), (-0.5740385944487281cx, 0.8459360881864443cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.5289738199212162cx, 0.9130102969856417cy), (-0.4373656215769072cx, 0.9754810632116981cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.35860967380728376cx, 0.9921248998878167cy), (-0.2410482750299296cx, 0.9704943621417292cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.16393657570822268cx, 0.9358477739619226cy), (-0.046034112529617026cx, 0.8438525425880632cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.014715277321585271cx, 0.7825131916604924c ...

# %%
Lines_m = Dict(i => [] for i in 1:33) # bus i is connected to lines Lines_m[i]
index = 1
for i in Lines
    push!(Lines_m[i[1]], index)
    push!(Lines_m[i[2]], index)
    index += 1
end

# %%
# points of interconnection?

# %% [markdown]
# ## Parameters

# %%
mask = (bus_system[!, :"From bus"] .== 1) .& (bus_system[!, :"To bus"] .== 2)
filtered_bus_system = bus_system[mask, :]
filtered_bus_system
# Out:
# 1×7 DataFrame
#  Row │ Branch No.  From bus  To bus  R (Ω)    X (Ω)    P (kW)  Q (kW)
#      │ Int64       Int64     Int64   Float64  Float64  Int64   Int64
# ─────┼────────────────────────────────────────────────────────────────
#    1 │          1         1       2   0.0922   0.0477       0       0

# %% [markdown]
# Let's fetch the resistance and reactance of each line from our table.

# %%
r_mn = Dict(i => 0. for i in Lines)
x_mn = Dict(i => 0. for i in Lines)

for i in Lines
    mask = (bus_system[!, :"From bus"] .== i[1]) .& (bus_system[!, :"To bus"] .== i[2])
    r_mn[i] = bus_system[mask, :][1, :"R (Ω)"]
    x_mn[i] = bus_system[mask, :][1, :"X (Ω)"]
end

# %%
p_m = Dict()
q_m = Dict()

for i in buses
    mask = bus_system[!, :"To bus"] .== i
    if ! isempty(bus_system[mask, :])
        p_m[i] = bus_system[mask, :][1, :"P (kW)"]
        q_m[i] = bus_system[mask, :][1, :"Q (kW)"]
    else
        p_m[i] = 0
        q_m[i] = 0
    end

end

# %% [markdown]
# We need to compute the admittance (conductance and susceptance) $g_{mn}$ and $b_{mn}$ from the impedance $r + i*x$

# %%
g_mn = Dict()
b_mn = Dict()

for i in Lines
    g_mn[i] = 1 / (r_mn[i]^2 + x_mn[i]^2) * (r_mn[i] ^2)
    b_mn[i] = - 1 / (r_mn[i]^2 + x_mn[i]^2) * (x_mn[i] ^2)
end

# %%
# Add in the set of interconnection points to bus m

C_m = Dict(i => [] for i in 1:33)

for i in Lines # for now we will suppose you can connect at every point
    C_m[i[1]] = [i[1]]
end
C_m
# Out:
# Dict{Int64, Vector{Any}} with 33 entries:
#   5  => [5]
#   16 => [16]
#   20 => [20]
#   12 => [12]
#   24 => [24]
#   28 => [28]
#   8  => [8]
#   17 => [17]
#   30 => [30]
#   1  => [1]
#   19 => [19]
#   22 => []
#   23 => [23]
#   6  => [6]
#   32 => [32]
#   11 => [11]
#   9  => [9]
#   31 => [31]
#   14 => [14]
#   ⋮  => ⋮

# %% [markdown]
# ## Variables

# %%
model = Model(Gurobi.Optimizer)

set_optimizer_attributes(model, "TimeLimit" => 60)

# Lines
@variable(model, pl_mn[1:length(Lines)])
@variable(model, ql_mn[1:length(Lines)])


# Buses
@variable(model, pD_m[buses]) # pD_m
@variable(model, pG_m[buses]) # pG_m
@variable(model, pM_c[buses]) # pM_c

@variable(model, qD_m[buses]) # qD_m
@variable(model, qG_m[buses]) # qG_m
@variable(model, qM_c[buses]) # q_Mc

@variable(model, V_m[buses])  # V_m voltage magnitude at m
@variable(model, θ_m[buses])  # θ_m voltage angle at m
@variable(model, ΔV_m[buses]) # ΔV_m voltage magnitude deviation at m
@variable(model, Δθ_m[buses]);# Δθ_m voltage angle deviation at m
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-18
# Set parameter TimeLimit to value 60

# %% [markdown]
# ## Equations
#
# ### Linear power flow equations
#
# We base the equations on (11), (12):
#
# $\forall m,n \space PL_{mn} = g_{mn} (\Delta V_m - \Delta V_n) + g_{mn} \Delta V_m  (\Delta V_m - \Delta V_n) - b_{mn} (\Delta \theta_m - \Delta \theta_n)$
#
#
# $\forall m,n \space QL_{mn} = -b_{mn} (\Delta V_m - \Delta V_n) - b_{mn} \Delta V_m  (\Delta V_m - \Delta V_n) - g_{mn} (\Delta \theta_m - \Delta \theta_n)$
#
# There is a non-linearity in there. For now, we will remove the non-linear term before reintroducing $\Delta \hat{V}_m$ as the solution of the lossless model.

# %%
for i in 1:length(Lines)
    m = Lines[i][1]
    n = Lines[i][2]
    @constraint(model, 
        pl_mn[i] ==   g_mn[Lines[i]] * (ΔV_m[m] - ΔV_m[n]) # + g_mn[Lines[i]] * ΔV_m[i[1]] * (ΔV_m[m] - ΔV_m[n]) 
                    - b_mn[Lines[i]] * (Δθ_m[m] - Δθ_m[n])
    )
    @constraint(model, 
        ql_mn[i] == - b_mn[Lines[i]] * (ΔV_m[m] - ΔV_m[n])  # - b_mn[Lines[i]] * ΔV_m[m] * (ΔV_m[m] - ΔV_m[n]) 
                    - g_mn[Lines[i]] * (Δθ_m[m] - Δθ_m[n])
    )
end


@constraint(model, -5 .<= pl_mn .<= 5) 
@constraint(model, -5 .<= ql_mn .<= 5)
# Out:
# 32-element Vector{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.Interval{Float64}}, ScalarShape}}:
#  ql_mn[1] in [-5, 5]
#  ql_mn[2] in [-5, 5]
#  ql_mn[3] in [-5, 5]
#  ql_mn[4] in [-5, 5]
#  ql_mn[5] in [-5, 5]
#  ql_mn[6] in [-5, 5]
#  ql_mn[7] in [-5, 5]
#  ql_mn[8] in [-5, 5]
#  ql_mn[9] in [-5, 5]
#  ql_mn[10] in [-5, 5]
#  ⋮
#  ql_mn[24] in [-5, 5]
#  ql_mn[25] in [-5, 5]
#  ql_mn[26] in [-5, 5]
#  ql_mn[27] in [-5, 5]
#  ql_mn[28] in [-5, 5]
#  ql_mn[29] in [-5, 5]
#  ql_mn[30] in [-5, 5]
#  ql_mn[31] in [-5, 5]
#  ql_mn[32] in [-5, 5]

# %% [markdown]
# ### Power balance equations

# %%
for m in buses
    @constraint(model, 
          pG_m[m] 
        + sum(pl_mn[line] for line in Lines_m[m]) 
        + sum(pM_c[c] for c in C_m[m]) 
        == pD_m[m])
    @constraint(model, 
           qG_m[m] 
        + sum(ql_mn[line] for line in Lines_m[m]) 
        + sum(qM_c[c] for c in C_m[m]) 
        == qD_m[m])
end

# %%
@constraint(model, 1 .>= pM_c[2:end] .>= -1)
@constraint(model, 1 .>= qM_c .>= -1)
# Out:
# 1-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.Interval{Float64}}, ScalarShape},1,...} with index sets:
#     Dimension 1, 1:33
# And data, a 33-element Vector{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.Interval{Float64}}, ScalarShape}}:
#  qM_c[1] in [-1, 1]
#  qM_c[2] in [-1, 1]
#  qM_c[3] in [-1, 1]
#  qM_c[4] in [-1, 1]
#  qM_c[5] in [-1, 1]
#  qM_c[6] in [-1, 1]
#  qM_c[7] in [-1, 1]
#  qM_c[8] in [-1, 1]
#  qM_c[9] in [-1, 1]
#  qM_c[10] in [-1, 1]
#  ⋮
#  qM_c[25] in [-1, 1]
#  qM_c[26] in [-1, 1]
#  qM_c[27] in [-1, 1]
#  qM_c[28] in [-1, 1]
#  qM_c[29] in [-1, 1]
#  qM_c[30] in [-1, 1]
#  qM_c[31] in [-1, 1]
#  qM_c[32] in [-1, 1]
#  qM_c[33] in [-1, 1]

# %%
@constraint(model, pM_c[1] == 40)
# Out:
# pM_c[1] == 40

# %%
@constraint(model, -0.5 .<= ΔV_m .<= 0.05)
@constraint(model, -0.5 .<= Δθ_m .<= 0.5)
# Out:
# 1-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.Interval{Float64}}, ScalarShape},1,...} with index sets:
#     Dimension 1, 1:33
# And data, a 33-element Vector{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.Interval{Float64}}, ScalarShape}}:
#  Δθ_m[1] in [-0.5, 0.5]
#  Δθ_m[2] in [-0.5, 0.5]
#  Δθ_m[3] in [-0.5, 0.5]
#  Δθ_m[4] in [-0.5, 0.5]
#  Δθ_m[5] in [-0.5, 0.5]
#  Δθ_m[6] in [-0.5, 0.5]
#  Δθ_m[7] in [-0.5, 0.5]
#  Δθ_m[8] in [-0.5, 0.5]
#  Δθ_m[9] in [-0.5, 0.5]
#  Δθ_m[10] in [-0.5, 0.5]
#  ⋮
#  Δθ_m[25] in [-0.5, 0.5]
#  Δθ_m[26] in [-0.5, 0.5]
#  Δθ_m[27] in [-0.5, 0.5]
#  Δθ_m[28] in [-0.5, 0.5]
#  Δθ_m[29] in [-0.5, 0.5]
#  Δθ_m[30] in [-0.5, 0.5]
#  Δθ_m[31] in [-0.5, 0.5]
#  Δθ_m[32] in [-0.5, 0.5]
#  Δθ_m[33] in [-0.5, 0.5]

# %%
for i in 1:33
    @constraint(model, pD_m[i] == p_m[i])
    @constraint(model, qD_m[i] == q_m[i])
end

# %% [markdown]
# ### Objective

# %%
@objective(
    model,
    Max,
    sum(pG_m)    
)
# Out:
# pG_m[1] + pG_m[2] + pG_m[3] + pG_m[4] + pG_m[5] + pG_m[6] + pG_m[7] + pG_m[8] + pG_m[9] + pG_m[10] + pG_m[11] + pG_m[12] + pG_m[13] + pG_m[14] + pG_m[15] + pG_m[16] + pG_m[17] + pG_m[18] + pG_m[19] + pG_m[20] + pG_m[21] + pG_m[22] + pG_m[23] + pG_m[24] + pG_m[25] + pG_m[26] + pG_m[27] + pG_m[28] + pG_m[29] + pG_m[30] + pG_m[31] + pG_m[32] + pG_m[33]

# %%
JuMP.optimize!(model)
# Out:
# Set parameter TimeLimit to value 60
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-12700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 392 rows, 589 columns and 1095 nonzeros
# Model fingerprint: 0xc2e42f1c
# Coefficient statistics:
#   Matrix range     [8e-02, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-02, 5e+00]
#   RHS range        [1e+01, 6e+02]
# Presolve removed 392 rows and 589 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.6847894e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  3.684789354e+03
#
# User-callback calls 48, time in user-callback 0.00 sec

# %%
bar(p_m, title="Power Generation at Each Bus", xlabel="Bus", ylabel="Power Generation (kW)")
bar!(value.(pG_m).data, title="Power Generation at Each Bus", xlabel="Bus", ylabel="Power Generation (kW)", alpha=0.5)

# %%
bar(q_m, title="Power Generation at Each Bus", xlabel="Bus", ylabel="Power Generation (kW)")
bar!(value.(qG_m).data, title="Power Generation at Each Bus", xlabel="Bus", ylabel="Power Generation (kW)", alpha=0.5)

# %%
bar(value.(V_m+ΔV_m).data)
